# %% [markdown]
# #problems
# 1. The transcript data we have is a bit less to procede with extracting proper topics because all the models expect a bit more data.
#
# ---
# #solutions
# 1. Using a countvectorizer to remove stop words(default) and mentioning it in the model declaration seems to have drastically improved the suggestions by the model.
#
# ---
#
# #observation
# * dividing the dialogs on the basis of its orginal form is better since combining all the dialogs seems to create worst results

# %%
# !pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 76 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 88 kB 8.3 MB/s
# ...
#      |████████████████████████████████| 85 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 5.2 MB 60.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 4.7 MB 58.7 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 66.5 MB/s
# ...
#      |████████████████████████████████| 101 kB 13.5 MB/s
# ...
#      |████████████████████████████████| 636 kB 69.0 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 54.1 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 41.9 MB/s
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp37-cp37m-linux_x86_64.whl size=2340293 sha256=05c8c65732c90a7890316b18d6ccc36d2344310afd36729959dd72c8c0cd2ca4
# ...

# %%
# !pip install pyLDAvis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.7 MB 13.4 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136898 sha256=8fb8ef92fdd705417a6265747d093ee16eecb57f9e69fc570960c70ea179c2e2
#   Stored in directory: /root/.cache/pip/wheels/c9/21/f6/17bcf2667e8a68532ba2fbf6d5c72fdf4c7f7d9abfa4852d2f
# Successfully built pyLDAvis
# ...

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups
import pandas as pd

# Sklearn
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from pprint import pprint
# Plotting tools
import pyLDAvis
import pyLDAvis.sklearn
import matplotlib.pyplot

import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import PorterStemmer
import numpy as np
np.random.seed(2018)

import spacy

from nltk import word_tokenize 

from hdbscan import HDBSCAN

# %%
import nltk

nltk.download('wordnet')

nltk.download("omw-1.4")

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# #Bert-Topic

# %%
with open("/content/full_company_data_current.txt","r") as f:
  full_data = [x.strip() for x in f.readlines()]
print(len(full_data))
# Out:
# 841

# %% [markdown]
# ##Default sentence-transformer Pipeline
#
#
#
# *   general flow is sentence-model->umap->hdbscan->ctfidf
# *   model used all-MiniLM-L6-v2

# %%
#using bertopic default pipeline
model = BERTopic()
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                  Name
# 0      -1    288                      -1_the_of_and_we
# 1       0    107                     0_care_and_the_to
# 2       1     69           1_question_thanks_thank_you
# 3       2     61                       2_we_to_the_and
# 4       3     43                   3_from_ago_loan_and
# 5       4     36                 4_customers_our_to_we
# 6       5     32                      5_that_the_q4_we
# 7       6     30       6_guidance_adjusted_nongaap_eps
# 8       7     27               7_russia_of_revenue_the
# 9       8     23      8_mailchimp_revenue_and_business
# 10      9     22                       9_we_the_and_of
# 11     10     19                  10_we_that_the_price
# 12     11     17                11_our_and_wells_fargo
# 13     12     15        12_karma_credit_money_platform
# 14     13     14         13_irs_returns_category_total
# 15     14     13                   14_think_we_be_here
# ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
##due to the presence of stop words adding count vectorizer 
vectorizer_model = CountVectorizer( stop_words="english",token_pattern='[a-zA-Z0-9]{3,}')
model = BERTopic(vectorizer_model=vectorizer_model)
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                       Name
# 0      -1    218         -1_revenue_growth_quarter_business
# 1       0    125                    0_year_ago_quarter_loan
# 2       1    118      1_customers_business_continue_product
# 3       2    107             2_care_optum_growth_valuebased
# 4       3     76          3_question_thanks_thank_questions
# 5       4     33         4_adjusted_guidance_nongaap_margin
# 6       5     29             5_china_open_shanghai_supplies
# 7       6     26               6_russia_revenue_billion_rpo
# 8       7     17  7_mailchimp_quickbooks_customers_business
# 9       8     17        8_billion_cash_shareholders_capital
# 10      9     16                  9_price_pricing_cost_time
# 11     10     15              10_irs_returns_category_total
# 12     11     15         11_turbotax_live_assisted_category
# 13     12     15             12_karma_credit_money_platform
# 14     13     14        13_think_spreads_certainly_declines

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#modifying hdbscan
#changing min_cluster_size can reduce outliers trying low size

hdbscan_model = HDBSCAN(min_cluster_size=5, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
model = BERTopic(hdbscan_model=hdbscan_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                           Name
# 0      -1    265                    -1_year_business_think_just
# 1       0     56              0_question_thanks_thank_questions
# 2       1     42               1_guidance_nongaap_adjusted_gaap
# 3       2     32      2_customers_marketing_customer_delivering
# 4       3     26                      3_business_tip_look_world
# 5       4     19                      4_loan_ago_banking_driven
# 6       5     19               5_optum_care_valuebased_patients
# 7       6     19              6_russia_belarus_extra_operations
# 8       7     18              7_turbotax_live_assisted_category
# 9       8     18                  8_care_important_seeing_homes
# 10      9     18                9_fargo_wells_advisers_separate
# 11     10     18                   10_gives_half_second_quarter
# 12     11     17                11_think_spreads_point_evaluate
# 13     12     15                12_china_open_shanghai_supplies
# ...

# %%
model.visualize_barchart(top_n_topics=40)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#modifying hdbscan
#changing min_cluster_size can reduce outliers trying high size

hdbscan_model = HDBSCAN(min_cluster_size=15, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
model = BERTopic(hdbscan_model=hdbscan_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#    Topic  Count                                  Name
# 0     -1    141     -1_revenue_business_quarter_think
# 1      0    431         0_year_quarter_think_business
# 2      1    107             1_care_optum_growth_think
# 3      2     67     2_question_thanks_thank_questions
# 4      3     51           3_turbotax_credit_karma_irs
# 5      4     24        4_china_open_shanghai_supplies
# 6      5     20  5_mailchimp_revenue_customers_growth

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#using MeanShift alogrithm
from sklearn.cluster import MeanShift

MeanShift_model = MeanShift()
model = BERTopic(hdbscan_model=MeanShift_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#    Topic  Count                         Name
# 0      0    841  0_year_quarter_think_growth

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#using KMeans alogrithm
from sklearn.cluster import KMeans

KMeans_model = KMeans()
model = BERTopic(hdbscan_model=KMeans_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#    Topic  Count                                  Name
# 0      0    146             0_think_just_right_really
# 1      1    140  1_business_customers_platform_really
# 2      2    110    2_billion_revenue_guidance_quarter
# 3      3    107             3_care_optum_think_growth
# 4      4     94               4_ago_loan_year_quarter
# 5      5     84     5_turbotax_credit_karma_customers
# 6      6     83             6_china_just_think_supply
# 7      7     77     7_thanks_question_thank_questions

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## all-MiniLM-L12-v2
#
#
#
# *   general flow is sentence-model->umap->hdbscan->ctfidf

# %%
model_name = "all-MiniLM-L12-v2"

# %%
#using bertopic default pipeline

model = BERTopic(embedding_model=model_name)
topics_custom, probs_custom = model.fit_transform(full_data)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/573 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/134M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/352 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                   Name
# 0      -1    226                       -1_the_and_we_of
# 1       0    119                       0_we_that_the_it
# 2       1     99                       1_we_and_our_the
# 3       2     59            2_question_thanks_thank_for
# 4       3     55                     3_from_ago_the_and
# 5       4     49                   4_progress_we_our_so
# 6       5     30                    5_and_our_in_pharma
# 7       6     27        6_gaap_guidance_adjusted_margin
# 8       7     25                  7_optum_care_value_to
# 9       8     21                      8_care_to_that_of
# 10      9     18                   9_call_our_and_thank
# 11     10     15                10_turbotax_live_is_and
# 12     11     15             11_billion_cash_to_capital
# 13     12     14  12_mailchimp_and_quickbooks_customers
# 14     13     12       13_revenue_mailchimp_grew_growth
# 15     14     12                     14_it_how_about_so
# ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
##due to the presence of stop words adding count vectorizer 
vectorizer_model = CountVectorizer( stop_words="english",token_pattern='[a-zA-Z0-9]{3,}')
model = BERTopic(vectorizer_model=vectorizer_model,embedding_model=model_name)
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                        Name
# 0      -1    271             -1_business_revenue_growth_year
# 1       0     95                    0_think_just_right_going
# 2       1     58            1_guidance_adjusted_gaap_billion
# 3       2     57           2_question_thanks_thank_questions
# 4       3     55                  3_ago_loan_quarter_deposit
# 5       4     51   4_capabilities_product_customers_continue
# 6       5     49                5_progress_esg_strategy_team
# 7       6     32       6_pharma_mass_spectrometry_pharmacies
# 8       7     24                   7_optum_care_value_health
# 9       8     18               8_care_covid_important_seeing
# 10      9     18             9_thank_today_questions_joining
# 11     10     17          10_billion_backlog_product_revenue
# 12     11     16                          11_lot_try_let_way
# 13     12     15              12_turbotax_live_assisted_sort
# ...

# %%
model.visualize_barchart(top_n_topics=18)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# model.visualize_topics()

# %%
#modifying hdbscan
#changing min_cluster_size can reduce outliers trying low size

hdbscan_model = HDBSCAN(min_cluster_size=5, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
model = BERTopic(embedding_model=model_name,hdbscan_model=hdbscan_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                           Name
# 0      -1    224                  -1_year_think_business_really
# 1       0     60              0_question_thanks_thank_questions
# 2       1     54                     1_ago_loan_deposit_quarter
# 3       2     45                  2_progress_esg_strategy_great
# 4       3     31        3_capabilities_product_customers_unique
# 5       4     30                  4_billion_revenue_rpo_backlog
# 6       5     26                      5_optum_care_value_health
# 7       6     23                  6_care_important_covid_seeing
# 8       7     19                  7_thank_joining_today_morning
# 9       8     19      8_mass_pharma_spectrometry_chromatography
# 10      9     19                        9_think_right_just_look
# 11     10     18           10_russia_quarter_belarus_operations
# 12     11     17     11_billion_cash_approximately_shareholders
# 13     12     16               12_cisco_intuit_group_statements
# ...

# %%
model.visualize_barchart(top_n_topics=34)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#modifying hdbscan
#changing min_cluster_size can reduce outliers trying high size

hdbscan_model = HDBSCAN(min_cluster_size=15, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
model = BERTopic(embedding_model=model_name,hdbscan_model=hdbscan_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#    Topic  Count                                        Name
# 0     -1    291              -1_revenue_year_business_think
# 1      0     93            0_business_customers_really_just
# 2      1     93                  1_think_just_right_quarter
# 3      2     61                   2_care_optum_value_people
# 4      3     59              3_progress_continue_team_great
# 5      4     59               4_gaap_adjusted_guidance_year
# 6      5     58           5_question_thanks_thank_questions
# 7      6     52                 6_turbotax_credit_karma_irs
# 8      7     47                     7_ago_loan_quarter_year
# 9      8     28  8_pharma_pharmacies_bioproduction_pharmacy

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#using MeanShift alogrithm
from sklearn.cluster import MeanShift

MeanShift_model = MeanShift()
model = BERTopic(embedding_model=model_name,hdbscan_model=MeanShift_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#    Topic  Count                         Name
# 0      0    841  0_year_quarter_growth_think

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# model.visualize_topics()

# %%
#using KMeans alogrithm
from sklearn.cluster import KMeans

KMeans_model = KMeans()
model = BERTopic(embedding_model=model_name,hdbscan_model=KMeans_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#    Topic  Count                                Name
# 0      0    171    0_business_customers_just_really
# 1      1    124          1_think_right_just_quarter
# 2      2    107      2_year_revenue_billion_quarter
# 3      3     99           3_care_optum_value_really
# 4      4     91             4_ago_year_loan_quarter
# 5      5     89  5_progress_continue_forward_growth
# 6      6     82   6_turbotax_credit_karma_mailchimp
# 7      7     78   7_thanks_question_thank_questions

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## all-mpnet-base-v2
#
#
#
# *   general flow is sentence-model->umap->hdbscan->ctfidf
# * much better model as suggested in the docs of bertopic but it is a heavy model

# %%
model_name = "all-mpnet-base-v2"

# %%
#using bertopic default pipeline

model = BERTopic(embedding_model=model_name)
topics_custom, probs_custom = model.fit_transform(full_data)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                Name
# 0      -1    253                    -1_we_the_and_of
# 1       0    105                   0_to_care_the_and
# 2       1     74         1_thanks_question_you_thank
# 3       2     71              2_the_year_to_guidance
# 4       3     43                    3_our_and_we_the
# 5       4     43                    4_we_the_so_very
# 6       5     43                     5_and_our_to_we
# 7       6     38          6_turbotax_irs_returns_the
# 8       7     34                7_from_ago_loan_year
# 9       8     33                  8_think_you_we_see
# 10      9     26  9_mailchimp_revenue_and_quickbooks
# 11     10     22                10_pricing_the_we_of
# 12     11     17                  11_that_we_what_of
# 13     12     15        12_credit_platform_karma_and
# 14     13     13                13_cisco_our_the_and
# 15     14     11           14_backlog_orders_ve_that

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
##due to the presence of stop words adding count vectorizer 
vectorizer_model = CountVectorizer( stop_words="english",token_pattern='[a-zA-Z0-9]{3,}')
model = BERTopic(vectorizer_model=vectorizer_model,embedding_model=model_name)
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#    Topic  Count                               Name
# 0      0    729        0_year_quarter_think_growth
# 1      1     74  1_question_thanks_thank_questions
# 2      2     38        2_turbotax_irs_returns_live

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# model.visualize_topics()

# %%
#modifying hdbscan
#changing min_cluster_size can reduce outliers trying low size

hdbscan_model = HDBSCAN(min_cluster_size=5, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
model = BERTopic(embedding_model=model_name,hdbscan_model=hdbscan_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                           Name
# 0      -1    219              -1_business_really_think_continue
# 1       0     73              0_thanks_question_thank_questions
# 2       1     62               1_adjusted_guidance_billion_year
# 3       2     44                        2_think_point_rate_just
# 4       3     38                    3_turbotax_irs_returns_live
# 5       4     35   4_capabilities_customers_product_proposition
# 6       5     34                     5_ago_loan_higher_balances
# 7       6     28      6_outstanding_excellent_performance_gives
# 8       7     24                       7_optum_care_value_based
# 9       8     20                    8_care_covid_home_important
# 10      9     19            9_open_supplies_shanghai_components
# 11     10     17              10_backlog_orders_cancelable_peak
# 12     11     16                11_pricing_price_cost_inflation
# 13     12     16            12_mass_spectrometry_pharma_biotech
# ...

# %%
model.visualize_barchart(top_n_topics=40)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#modifying hdbscan
#changing min_cluster_size can reduce outliers trying high size

hdbscan_model = HDBSCAN(min_cluster_size=15, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
model = BERTopic(embedding_model=model_name,hdbscan_model=hdbscan_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#    Topic  Count                               Name
# 0      0    728        0_year_quarter_think_growth
# 1      1     73  1_question_thanks_thank_questions
# 2      2     40        2_turbotax_irs_returns_live

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# model.visualize_topics()

# %%
#using MeanShift alogrithm
from sklearn.cluster import MeanShift

MeanShift_model = MeanShift()
model = BERTopic(embedding_model=model_name,hdbscan_model=MeanShift_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#    Topic  Count                               Name
# 0      0    767        0_year_quarter_growth_think
# 1      1     74  1_question_thanks_thank_questions

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# model.visualize_topics()

# %%
#using KMeans alogrithm
from sklearn.cluster import KMeans

KMeans_model = KMeans()
model = BERTopic(embedding_model=model_name,hdbscan_model=KMeans_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)

# %%
model.get_topic_info()
# Out:
#    Topic  Count                                   Name
# 0      0    181      0_really_business_growth_continue
# 1      1    146               1_think_just_right_going
# 2      2    108  2_business_customers_revenue_platform
# 3      3    107         3_year_revenue_billion_quarter
# 4      4    103                4_ago_year_quarter_loan
# 5      5     83              5_care_optum_value_people
# 6      6     73      6_thanks_question_thank_questions
# 7      7     40            7_turbotax_irs_returns_live

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##finbert
#
# * finbert is a very special model as it is a pre-trained NLP model to analyze sentiment of financial text.

# %%
model_name = "ProsusAI/finbert"

# %%
#using bertopic default pipeline

model = BERTopic(embedding_model=model_name)
topics_custom, probs_custom = model.fit_transform(full_data)
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/758 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/252 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/ProsusAI_finbert. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/ProsusAI_finbert were not used when initializing BertModel: ['classifier.weight', 'classifier.bias']
# ...

# %%
model.get_topic_info()
# Out:
#    Topic  Count             Name
# 0      0    685  0_the_we_and_to
# 1      1    156  1_the_in_and_to

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# model.visualize_topics()

# %%
##due to the presence of stop words adding count vectorizer 
vectorizer_model = CountVectorizer( stop_words="english",token_pattern='[a-zA-Z0-9]{3,}')
model = BERTopic(vectorizer_model=vectorizer_model,embedding_model=model_name)
topics_custom, probs_custom = model.fit_transform(full_data)
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/ProsusAI_finbert. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/ProsusAI_finbert were not used when initializing BertModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
model.get_topic_info()
# Out:
#    Topic  Count                                  Name
# 0     -1    153            -1_time_care_business_good
# 1      0    216               0_think_just_look_right
# 2      1    154         1_year_revenue_quarter_growth
# 3      2    125  2_customers_continue_growth_business
# 4      3     53    3_really_value_capabilities_seeing
# 5      4     46   4_statements_website_turn_financial
# 6      5     33          5_quality_really_things_time
# 7      6     31     6_thanks_thank_question_questions
# 8      7     19       7_really_business_strong_season
# 9      8     11            8_times_just_question_sort

# %%
model.visualize_barchart(top_n_topics=18)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# model.visualize_topics()

# %%
#modifying hdbscan
#changing min_cluster_size can reduce outliers trying low size

hdbscan_model = HDBSCAN(min_cluster_size=5, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
model = BERTopic(embedding_model=model_name,hdbscan_model=hdbscan_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/ProsusAI_finbert. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/ProsusAI_finbert were not used when initializing BertModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                             Name
# 0      -1    253                    -1_just_think_really_business
# 1       0    155                   0_year_revenue_billion_quarter
# 2       1     38               1_customers_consumers_new_platform
# 3       2     32                2_thanks_thank_question_questions
# 4       3     30                       3_question_maybe_think_don
# 5       4     24                 4_good_strong_performing_deliver
# 6       5     24                5_situation_right_russia_supplies
# 7       6     23                  6_strong_growth_proven_strategy
# 8       7     22                      7_pretty_think_going_little
# 9       8     22              8_statements_website_financial_gaap
# 10      9     21                     9_really_business_tip_season
# 11     10     20                    10_able_quality_choice_things
# 12     11     19                         11_think_number_look_lot
# ...

# %%
model.visualize_barchart(top_n_topics=34)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#modifying hdbscan
#changing min_cluster_size can reduce outliers trying high size

hdbscan_model = HDBSCAN(min_cluster_size=15, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
model = BERTopic(embedding_model=model_name,hdbscan_model=hdbscan_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/ProsusAI_finbert. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/ProsusAI_finbert were not used when initializing BertModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
model.get_topic_info()
# Out:
#    Topic  Count                                  Name
# 0     -1     65         -1_quarter_care_grew_business
# 1      0    421             0_think_just_really_going
# 2      1    152         1_year_revenue_quarter_growth
# 3      2    125  2_customers_continue_growth_business
# 4      3     46     3_statements_website_results_gaap
# 5      4     32     4_thanks_thank_question_questions

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#using MeanShift alogrithm
from sklearn.cluster import MeanShift

MeanShift_model = MeanShift()
model = BERTopic(embedding_model=model_name,hdbscan_model=MeanShift_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/ProsusAI_finbert. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/ProsusAI_finbert were not used when initializing BertModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
model.get_topic_info()
# Out:
#    Topic  Count                           Name
# 0      0    429  0_year_growth_revenue_quarter
# 1      1    412       1_think_just_look_really

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# model.visualize_topics()

# %%
#using KMeans alogrithm
from sklearn.cluster import KMeans

KMeans_model = KMeans()
model = BERTopic(embedding_model=model_name,hdbscan_model=KMeans_model,vectorizer_model=vectorizer_model,calculate_probabilities=True)
topics_custom, probs_custom = model.fit_transform(full_data)
# Out:
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/ProsusAI_finbert. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/ProsusAI_finbert were not used when initializing BertModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
model.get_topic_info()
# Out:
#    Topic  Count                                  Name
# 0      0    143  0_customers_continue_business_growth
# 1      1    142            1_think_just_quarter_going
# 2      2    123           2_really_seeing_think_going
# 3      3    103         3_revenue_year_growth_billion
# 4      4     99         4_business_time_platform_just
# 5      5     99             5_think_just_question_don
# 6      6     82    6_thanks_thank_question_statements
# 7      7     50             7_year_driven_quarter_ago

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #LDA Analysis
# * will perform lda analysis on Complete data

# %%
stemmer = PorterStemmer()

# %%
with open("/content/full_company_data_current.txt","r") as f:
  full_data = [x.strip() for x in f.readlines()]
print(len(full_data))
# Out:
# 841

# %%
custom_data = full_data

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations
data_words = list(sent_to_words(custom_data))
print(data_words[2])
# Out:
# ['so', 'before', 'we', 'begin', 'let', 'me', 'briefly', 'cover', 'our', 'safe', 'harbor', 'statement', 'various', 'remarks', 'that', 'we', 'may', 'make', 'about', 'the', 'company', 'future', 'expectations', 'plans', 'and', 'prospects', 'constitute', 'forward', 'looking', 'statements', 'for', 'purposes', 'of', 'the', 'safe', 'harbor', 'provisions', 'under', 'the', 'private', 'securities', 'litigation', 'reform', 'act', 'of', 'actual', 'results', 'may', 'differ', 'materially', 'from', 'those', 'indicated', 'by', 'these', 'forward', 'looking', 'statements', 'as', 'result', 'of', 'various', 'important', 'factors', 'including', 'those', 'discussed', 'in', 'the', 'company', 'most', 'recent', 'annual', 'report', 'on', 'form', 'and', 'subsequent', 'quarterly', 'report', 'on', 'form', 'which', 'are', 'on', 'file', 'with', 'the', 'sec', 'and', 'available', 'in', 'the', 'investors', 'section', 'of', 'our', 'website', 'under', 'the', 'heading', 'financials', 'sec', 'filings']

# %%
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])

# %%
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ']): #'NOUN', 'ADJ', 'VERB', 'ADV'
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append(" ".join([token.lemma_ if token.lemma_ not in ['-PRON-'] else '' for token in doc if token.pos_ in allowed_postags]))
    return texts_out

# %%
data_lemmatized = lemmatization(data_words, allowed_postags=["NOUN","ADJ"]) #select noun and verb
print(data_lemmatized[:2])
# Out:
# ['good morning', 'call today chairman president chief executive officer senior vice president chief financial officer call webcast investor section website com heading news event copy press release second quarter earning available investor section website heading financial']

# %%
  
class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, articles):
        return [self.wnl.lemmatize(t) for t in word_tokenize(articles)]

# %%
vectorizer_tfidf = TfidfVectorizer()#dangerous

# %%
#ngram (1,3)
vectorizer = CountVectorizer(analyzer='word',                                
                             min_df=10,

# minimum reqd occurences of a word 
                             stop_words='english',             
# remove stop words
                             lowercase=True,                   
# convert all words to lowercase
                             token_pattern='[a-zA-Z0-9]{3,}'  
# num chars > 3
                             # max_features=50000,             
# max number of uniq words    
)
data_vectorized = vectorizer.fit_transform(data_lemmatized)

# %%
# Build LDA Model
lda_model = LatentDirichletAllocation(n_components=10,               # Number of topics
                                      max_iter=15,               
# Max learning iterations
                                      learning_method='batch',   
                                      random_state=100,          
# Random state
                                      batch_size=128,            
# n docs in each learning iter
                                      evaluate_every = -1,       
# compute perplexity every n iters, default: Don't
                                      n_jobs = -1,               
# Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(data_vectorized)
print(lda_model)
# Out:
# LatentDirichletAllocation(max_iter=15, n_jobs=-1, random_state=100)

# %%
lda_output
# Out:
# array([[0.03333333, 0.03333419, 0.03333333, ..., 0.03333532, 0.03333333,
#         0.69999425],
#        [0.00833357, 0.92498781, 0.00833366, ..., 0.00833786, 0.0083336 ,
#         0.00833486],
#        [0.00666789, 0.93998845, 0.0066672 , ..., 0.00667023, 0.00666686,
#         0.00666754],
#        ...,
#        [0.55      , 0.05      , 0.05      , ..., 0.05      , 0.05      ,
#         0.05      ],
#        [0.38544018, 0.02000044, 0.02000546, ..., 0.45454241, 0.0200018 ,
#         0.02      ],
#        [0.02000203, 0.02001222, 0.81995964, ..., 0.02000277, 0.02000325,
#         0.02001589]])

# %%
# Log Likelyhood: Higher the better
print("Log Likelihood: ", lda_model.score(data_vectorized))
# Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
print("Perplexity: ", lda_model.perplexity(data_vectorized))
# See model parameters
pprint(lda_model.get_params())
# Out:
# Log Likelihood:  -40767.92918542806
# Perplexity:  186.29431430265473
# {'batch_size': 128,
#  'doc_topic_prior': None,
#  'evaluate_every': -1,
#  'learning_decay': 0.7,
#  'learning_method': 'batch',
#  'learning_offset': 10.0,
#  'max_doc_update_iter': 100,
#  'max_iter': 15,
#  'mean_change_tol': 0.001,
#  'n_components': 10,
#  'n_jobs': -1,
#  'perp_tol': 0.1,
#  'random_state': 100,
#  'topic_word_prior': None,
#  'total_samples': 1000000.0,
#  'verbose': 0}

# %%
# Define Search Param
search_params = {'n_components': [ 5, 10, 15, 20, 25, 30], 'learning_decay': [.4, .5, .7, .9]}
# Init the Model
lda = LatentDirichletAllocation(max_iter=5, learning_method='batch', learning_offset=50.,random_state=0)
# Init Grid Search Class
model = GridSearchCV(lda, param_grid=search_params)
# Do the Grid Search
model.fit(data_vectorized)
GridSearchCV(cv=None, error_score='raise',
       estimator=LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
             evaluate_every=-1, learning_decay=0.7, learning_method=None,
             learning_offset=10.0, max_doc_update_iter=100, max_iter=15,
             mean_change_tol=0.001, n_components=None, n_jobs=1,
      perp_tol=0.1, random_state=None,
             topic_word_prior=None, total_samples=1000000.0, verbose=0), n_jobs=1,
       param_grid={'n_components': [5,10, 15, 20, 25, 30], 'learning_decay': [0.5, 0.7, 0.9]},
       pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
       scoring=None, verbose=0)
# Out:
# GridSearchCV(error_score='raise',
#              estimator=LatentDirichletAllocation(learning_method=None,
#                                                  max_iter=15, n_components=None,
#                                                  n_jobs=1),
#              n_jobs=1,
#              param_grid={'learning_decay': [0.5, 0.7, 0.9],
#                          'n_components': [5, 10, 15, 20, 25, 30]},
#              return_train_score='warn')

# %%
# Best Model
best_lda_model = model.best_estimator_
# Model Parameters
print("Best Model's Params: ", model.best_params_)
# Log Likelihood Score
print("Best Log Likelihood Score: ", model.best_score_)
# Perplexity
print("Model Perplexity: ", best_lda_model.perplexity(data_vectorized))
# Out:
# Best Model's Params:  {'learning_decay': 0.4, 'n_components': 5}
# Best Log Likelihood Score:  -10271.339344183036
# Model Perplexity:  191.56355315698838

# %%
# Create Document — Topic Matrix
lda_output = best_lda_model.transform(data_vectorized)
# column names
topicnames = ["Topic"+ str(i) for i in range(best_lda_model.n_components)]
# index names
docnames = ["Doc" + str(i) for i in range(len(custom_data))]
# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(lda_output, 2), columns=topicnames, index=docnames)
# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic["dominant_topic"] = dominant_topic
# Styling
def color_green(val):
 color = "green" if val > .1 else "black"
 return "color: {col}".format(col=color)
def make_bold(val):
 weight = 700 if val > .1 else 400
 return "font-weight: {weight}".format(weight=weight)
# Apply Style
df_document_topics = df_document_topic.head(15).style.applymap(color_green).applymap(make_bold)
df_document_topics
# Out:
# <style type="text/css">
# ...

# %%
# Topic-Keyword Matrix
df_topic_keywords = pd.DataFrame(best_lda_model.components_)
# Assign Column and Index
df_topic_keywords.columns = vectorizer.get_feature_names()
df_topic_keywords.index = topicnames
# View
df_topic_keywords.head()
# Out:
#              able     access  acquisition    action  activity  additional  \
# Topic0   0.314569   0.821300     0.200639  4.866311  5.093830    8.327931
# Topic1   8.841090  11.231534     6.577651  0.201484  0.202444    0.200569
# Topic2   0.321024   0.202260     0.216051  2.879200  0.200568    1.427058
# Topic3  15.308430   6.544899     0.201058  0.245930  8.240485    1.364362
# Topic4   0.214886   0.200007     7.804601  4.807075  2.262673    2.680080
#
#         appropriate       area      asset  available  ...  uncertainty  \
# Topic0     0.200838   0.200166  15.630079   0.201664  ...     0.200990
# Topic1     8.718590  24.866785   0.512473   0.266272  ...     2.197090
# Topic2     0.209692   0.275747   0.255391   7.027394  ...     1.285412
# Topic3     2.422421   4.153226   1.401900   5.303068  ...     5.300280
# Topic4     0.448458   0.504077   0.200156   0.201601  ...     2.016228
#
#           unique      value   virtual     volume        way      week  \
# ...

# %%
# Show top n keywords for each topic
def show_topics(vectorizer=vectorizer, lda_model=lda_model, n_words=5):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in lda_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords
topic_keywords = show_topics(vectorizer=vectorizer, lda_model=best_lda_model, n_words=5)
# Topic - Keywords Dataframe
df_topic_keywords = pd.DataFrame(topic_keywords)
df_topic_keywords.columns = ['Word '+str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords.index = ['Topic '+str(i) for i in range(df_topic_keywords.shape[0])]
df_topic_keywords
# Out:
#            Word 0    Word 1    Word 2    Word 3    Word 4
# Topic 0      year   revenue   quarter    growth      rate
# Topic 1      time  platform  business      care  customer
# Topic 2    growth  customer   quarter  business     point
# Topic 3      year      high      term   product      gaap
# Topic 4  business      year  question   quarter   revenue

# %%
import pyLDAvis
import pyLDAvis.sklearn

# %%
pyLDAvis.enable_notebook()
pyLDAvis.sklearn.prepare(best_lda_model, data_vectorized, vectorizer)
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.190874  0.026583       1        1  24.789480
# 4     -0.064629 -0.161088       2        1  20.396826
# 1      0.237578 -0.021083       3        1  20.283294
# 3     -0.008495  0.127134       4        1  17.374947
# 2      0.026419  0.028455       5        1  17.155452, topic_info=         Term        Freq       Total Category  logprob  loglift
# 176  question   77.000000   77.000000  Default  30.0000  30.0000
# 225      time  104.000000  104.000000  Default  29.0000  29.0000
# 239      year  333.000000  333.000000  Default  28.0000  28.0000
# 161  platform   73.000000   73.000000  Default  27.0000  27.0000
# 189   revenue  167.000000  167.000000  Default  26.0000  26.0000
# ..        ...         ...         ...      ...      ...      ...
# 201   service   14.014621   56.008348   Topic5  -4.5588   0.3775
# 15      basis   13.417256   47.654164   Topic5  -4.6024   0.4954
# ...
